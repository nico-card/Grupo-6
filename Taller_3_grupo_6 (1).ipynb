# %% [markdown]
# 1. Cree una imagen de un canal, es decir con una forma (alto, ancho) del tamaño que desee, donde la diagonal principal hacia arriba sea blanca y desde la diagonal hacia abajo sea negra.

# %%
import numpy as npy  # primero debemos importar la libreria que en este caso es numpy
from skimage import data # Ahora importamos el submodulo de la biblioteca skimage
import matplotlib.pyplot as plt # importamos el paquete matplotlib.pyplot  
c=[] # declaramos una matriz vacia
for a in range(0,50): #Establecemos un bucle for para a de 0 a 50 (Ancho eje x)
  h=[] # Establecemos una linsta en donde guardaremos los datos
  for b in range (0,50): #Establecemos un bucle for para a de 0 a 50 ( Alto eje y)
    if b<a: # ponemos una condicion de si b es mayor que a entonces...
     p=[0,0,0] #designamos 0 es decir el color negro a todos los valores de p
    else: #entonces si no se cumple la condicion anterior entonces...
     p=[255,255,255] # designamos 255 (el cual es el color blanco) a todos los valores del pixel
    h.append(p) #al final de cada ciclo del for anidado añadimos la viarable p la cual es de pixel a la lista 
  c.append(h)#al final de cada ciclo del primer for o for "principal" se añade la lista y todos los datos añadidos a la matriz h
plt.imshow(c) #se muestra en la pantalla la imagen creada

# %%
import matplotlib.pyplot as plt#importamos la libreria matplotlib.pyplot
from skimage import data  #Importamos la base de datos de donde obtendremos la imagen
from skimage import feature #Importarmos los rasgos 
from skimage.color import rgb2gray # Esto es para transformar de RGB a escala de grises
a=data.coffee()# ponemos desde la base de datos la imagen de esta que en este caso  es stereo_motorcycle a a 
b=rgb2gray(a) #Aplicamos la escala de grises a la imagen
edge=feature.canny(b) #Aplicamos el filtro canny
plt.imshow(edge) #mostrarmos los datos como una imagen
plt.show()#Mostrar todas las figuras abiertas
